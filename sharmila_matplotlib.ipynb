# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmijayabal/Data-science/blob/main/sharmila_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# MATPLOTLIB
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-033bc9c8-f661-4f06-9b0a-a0bfc445d2b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-033bc9c8-f661-4f06-9b0a-a0bfc445d2b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df= pd.read_csv('Cardiovascular_Disease_Dataset.csv')

# %%
df
# Out:
#      patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0       103368   53       1          2        171                0
# 1       119250   40       1          0         94              229
# 2       119372   49       1          2        133              142
# 3       132514   43       1          0        138              295
# 4       146211   31       1          1        199                0
# ..         ...  ...     ...        ...        ...              ...
# 995    9949544   48       1          2        139              349
# 996    9953423   47       1          3        143              258
# 997    9965859   69       1          0        156              434
# 998    9988507   45       1          1        186              417
# 999    9990855   25       1          0        158              270
#
#      fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                    0                1           147              0      5.3
# ...

# %%
df.shape
# Out:
# (1000, 14)

# %%
df.plot()
# Out:
# <Axes: >

# %%
df=df.drop(columns='oldpeak')

# %%
df.columns
# Out:
# Index(['age', 'gender', 'chestpain', 'restingBP', 'serumcholestrol',
#        'fastingbloodsugar', 'restingrelectro', 'maxheartrate', 'exerciseangia',
#        'slope', 'noofmajorvessels', 'target'],
#       dtype='object')

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(figsize=(5,10))
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    age  gender  chestpain  restingBP  serumcholestrol  fastingbloodsugar  \
# 0   53       1          2        171                0                  0
# 1   40       1          0         94              229                  0
# 2   49       1          2        133              142                  0
# 3   43       1          0        138              295                  1
# 4   31       1          1        199                0                  0
#
#    restingrelectro  maxheartrate  exerciseangia  slope  noofmajorvessels  \
# 0                1           147              0      3                 3
# 1                1           115              0      1                 1
# 2                0           202              1      1                 0
# 3                1           153              0      2                 2
# 4                2           136              0      3                 2
#
#    target
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1

# %%
df['gender'].hist()
# Out:
# <Axes: >

# %%
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
df.iloc[2][0:5]
# Out:
# age                 49
# gender               1
# chestpain            2
# restingBP          133
# serumcholestrol    142
# Name: 2, dtype: int64

# %%
df
# Out:
#      age  gender  chestpain  restingBP  serumcholestrol  fastingbloodsugar  \
# 0     53       1          2        171                0                  0
# 1     40       1          0         94              229                  0
# 2     49       1          2        133              142                  0
# 3     43       1          0        138              295                  1
# 4     31       1          1        199                0                  0
# ..   ...     ...        ...        ...              ...                ...
# 995   48       1          2        139              349                  0
# 996   47       1          3        143              258                  1
# 997   69       1          0        156              434                  1
# 998   45       1          1        186              417                  0
# 999   25       1          0        158              270                  0
#
# ...

# %%
df.head(30).plot(kind='bar')
# Out:
# <Axes: >

# %%
df.head(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
df.head(5).plot(kind='barh')
# Out:
# <Axes: >

# %%
df['gender'],df['fastingbloodsugar'].plot(kind='barh')
# Out:
# (0      1
#  1      1
#  2      1
#  3      1
#  4      1
#        ..
#  995    1
#  996    1
#  997    1
#  998    1
#  999    1
#  Name: gender, Length: 1000, dtype: int64,
#  <Axes: >)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                1000 non-null   int64
#  1   gender             1000 non-null   int64
#  2   chestpain          1000 non-null   int64
#  3   restingBP          1000 non-null   int64
#  4   serumcholestrol    1000 non-null   int64
#  5   fastingbloodsugar  1000 non-null   int64
#  6   restingrelectro    1000 non-null   int64
#  7   maxheartrate       1000 non-null   int64
#  8   exerciseangia      1000 non-null   int64
#  9   slope              1000 non-null   int64
#  10  noofmajorvessels   1000 non-null   int64
#  11  target             1000 non-null   int64
# dtypes: int64(12)
# memory usage: 93.9 KB

# %%
df_num=df.drop(columns=['exerciseangia'])

# %%
df_num
# Out:
#      age  gender  chestpain  restingBP  serumcholestrol  fastingbloodsugar  \
# 0     53       1          2        171                0                  0
# 1     40       1          0         94              229                  0
# 2     49       1          2        133              142                  0
# 3     43       1          0        138              295                  1
# 4     31       1          1        199                0                  0
# ..   ...     ...        ...        ...              ...                ...
# 995   48       1          2        139              349                  0
# 996   47       1          3        143              258                  1
# 997   69       1          0        156              434                  1
# 998   45       1          1        186              417                  0
# 999   25       1          0        158              270                  0
#
#      restingrelectro  maxheartrate  slope  noofmajorvessels  target
# ...

# %%
df_num.head(30).plot(kind='bar')
# Out:
# <Axes: >

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#               age       gender    chestpain    restingBP  serumcholestrol  \
# count  1000.00000  1000.000000  1000.000000  1000.000000      1000.000000
# mean     49.24200     0.765000     0.980000   151.747000       311.447000
# std      17.86473     0.424211     0.953157    29.965228       132.443801
# min      20.00000     0.000000     0.000000    94.000000         0.000000
# 25%      34.00000     1.000000     0.000000   129.000000       235.750000
# 50%      49.00000     1.000000     1.000000   147.000000       318.000000
# 75%      64.25000     1.000000     2.000000   181.000000       404.250000
# max      80.00000     1.000000     3.000000   200.000000       602.000000
#
#        fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  \
# count        1000.000000      1000.000000   1000.000000    1000.000000
# mean            0.296000         0.748000    145.477000       0.498000
# std             0.456719         0.770123     34.190268       0.500246
# ...

# %%
df.plot.box(grid=True)
# Out:
# <Axes: >

# %%
plt.violinplot(df_num)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7959bd099750>,
# ...
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7959bd0996f0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7959bd0d8130>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7959bd0d8670>}

# %%
plt.violinplot(df_num,showmeans=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7959bcf37820>,
# ...
#  'cmeans': <matplotlib.collections.LineCollection at 0x7959bcf377c0>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7959bcf66230>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7959bcf66770>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7959bcf66cb0>}

# %%
plt.violinplot(df_num,showmeans=True,showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7959bcdf63e0>,
# ...
#  'cmeans': <matplotlib.collections.LineCollection at 0x7959bcfafa00>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7959bce30a60>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7959bce30fa0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7959bce314e0>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x7959bce31a20>}

# %%
# heat map - numerical
plt.imshow(df)
plt.title("2 Dim Heat Map")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                1000 non-null   int64
#  1   gender             1000 non-null   int64
#  2   chestpain          1000 non-null   int64
#  3   restingBP          1000 non-null   int64
#  4   serumcholestrol    1000 non-null   int64
#  5   fastingbloodsugar  1000 non-null   int64
#  6   restingrelectro    1000 non-null   int64
#  7   maxheartrate       1000 non-null   int64
#  8   exerciseangia      1000 non-null   int64
#  9   slope              1000 non-null   int64
#  10  noofmajorvessels   1000 non-null   int64
#  11  target             1000 non-null   int64
# dtypes: int64(12)
# memory usage: 93.9 KB

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                1000 non-null   int64
#  1   gender             1000 non-null   int64
#  2   chestpain          1000 non-null   int64
#  3   restingBP          1000 non-null   int64
#  4   serumcholestrol    1000 non-null   int64
#  5   fastingbloodsugar  1000 non-null   int64
#  6   restingrelectro    1000 non-null   int64
#  7   maxheartrate       1000 non-null   int64
#  8   slope              1000 non-null   int64
#  9   noofmajorvessels   1000 non-null   int64
#  10  target             1000 non-null   int64
# dtypes: int64(11)
# memory usage: 86.1 KB

# %%
# heat map
plt.imshow(df_num)
plt.title("2 Dim Heat Map")
plt.show()

# %%
plt.imshow(df_num.head(10))
plt.title("2 Dim Heat Map")
plt.show()

# %%
plt.imshow(df_num.head(10),cmap='autumn')
plt.title("2 Dim Heat Map")
plt.show()

# %%
plt.imshow(df_num.head(10),cmap='gray')
plt.title("2 Dim Heat Map")
plt.show()

# %%
plt.imshow(df_num.head(10),cmap='autumn',interpolation='blackman')
plt.title("2 Dim Heat Map")
plt.show()

# %%
plt.imshow(df_num.head(10),cmap='autumn',interpolation='nearest')
plt.colorbar()
plt.title("2 Dim Heat Map")
plt.show()

# %%
plt.imshow(df_num.head(10),cmap='autumn',interpolation='nearest')
plt.colorbar(ticks=[1,3,5])
plt.title("2 Dim Heat Map")
plt.show()

# %%
df.corr()
# Out:
#                         age    gender  chestpain  restingBP  serumcholestrol  \
# age                1.000000 -0.024717   0.037731  -0.016126         0.035439
# gender            -0.024717  1.000000   0.035402  -0.069727        -0.120759
# chestpain          0.037731  0.035402   1.000000   0.222267         0.174731
# restingBP         -0.016126 -0.069727   0.222267   1.000000         0.126523
# serumcholestrol    0.035439 -0.120759   0.174731   0.126523         1.000000
# fastingbloodsugar  0.049732  0.023560   0.232059   0.192063         0.278337
# restingrelectro    0.067736 -0.046634   0.256316   0.219887         0.101767
# maxheartrate      -0.040092  0.064606   0.114496   0.095569         0.038967
# exerciseangia     -0.037581 -0.051746  -0.027376  -0.046545         0.029422
# slope             -0.015334 -0.051957   0.472731   0.376711         0.165569
# noofmajorvessels   0.025407  0.029376   0.285156   0.263194         0.132419
# ...

# %%
df.corr().plot()
# Out:
# <Axes: >

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>
